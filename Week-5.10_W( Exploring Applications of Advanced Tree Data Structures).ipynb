# %% [markdown]
# <a href="https://colab.research.google.com/github/kandhicharanyadav/Competitive-Programming/blob/main/Week-5.10_W(%20Exploring%20Applications%20of%20Advanced%20Tree%20Data%20Structures).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem - 1 :**

# %%
# -------- Segment Tree --------
class SegmentTree:
    def __init__(self, arr):
        self.n = len(arr)
        self.tree = [0] * (4 * self.n)
        self.build(arr, 0, 0, self.n - 1)

    # Build tree
    def build(self, arr, node, start, end):
        if start == end:
            self.tree[node] = arr[start]
        else:
            mid = (start + end) // 2
            self.build(arr, 2*node+1, start, mid)
            self.build(arr, 2*node+2, mid+1, end)
            self.tree[node] = self.tree[2*node+1] + self.tree[2*node+2]

    # Update value
    def update(self, node, start, end, idx, val):
        if start == end:
            self.tree[node] = val
        else:
            mid = (start + end)//2
            if idx <= mid:
                self.update(2*node+1, start, mid, idx, val)
            else:
                self.update(2*node+2, mid+1, end, idx, val)

            self.tree[node] = self.tree[2*node+1] + self.tree[2*node+2]

    # Range sum query
    def query(self, node, start, end, l, r):
        if r < start or end < l:
            return 0
        if l <= start and end <= r:
            return self.tree[node]

        mid = (start + end)//2
        left = self.query(2*node+1, start, mid, l, r)
        right = self.query(2*node+2, mid+1, end, l, r)
        return left + right


print("\n--- Segment Tree Range Sum ---")

# -------- INPUT --------
n = int(input("Enter number of days: "))

arr = list(map(int, input(
    "Enter revenue values (space-separated): "
).split()))

seg = SegmentTree(arr)

# First range query
l, r = map(int, input(
    "Enter range to find sum (left right): "
).split())

print("Range Sum =", seg.query(0, 0, n-1, l, r))

# Update
idx, val = map(int, input(
    "Enter index and new value to update: "
).split())

seg.update(0, 0, n-1, idx, val)

# Second query
l, r = map(int, input(
    "Enter range again to find updated sum: "
).split())

print("Updated Range Sum =", seg.query(0, 0, n-1, l, r))
# Out:
# --- Segment Tree Range Sum ---
# Enter number of days: 8
# Enter revenue values (space-separated): 5 3 8 6 2 7 4 9
# Enter range to find sum (left right): 2 6
# Range Sum = 27
# Enter index and new value to update: 4 10
# Enter range again to find updated sum: 2 6
# Updated Range Sum = 35
