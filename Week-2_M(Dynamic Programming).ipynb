# %% [markdown]
# <a href="https://colab.research.google.com/github/kandhicharanyadav/Competitive-Programming/blob/main/Week-2_M(Dynamic%20Programming).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Week 2 - Dynamic Programming**

# %%
# Fibonacci using Memoization

def fibonacci(n, memo):
    # Base cases
    if n == 0:
        return 0
    if n == 1:
        return 1

    # Check if value already computed
    if n in memo:
        return memo[n]

    # Recursive computation with memoization
    memo[n] = fibonacci(n - 1, memo) + fibonacci(n - 2, memo)
    return memo[n]


# Read input
n = int(input())

# Dictionary to store computed Fibonacci values
memo = {}

# Compute and print the result
result = fibonacci(n, memo)
print(result)
# Out:
# 10
# 55
